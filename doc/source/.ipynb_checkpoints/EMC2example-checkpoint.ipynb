# %% [markdown]
# # _EMC²_ Demo Notebook
#
# In this notebook we show an example of how to run $EMC^2$ using ModelE3 climate model output and high spectral resolution lidar (HSRL) data, and demonstrate some of the framework's plotting capabilities.

# %%
import emc2
import matplotlib.dates as mdates

# %% [markdown]
# First, we load model data (in this case, ModelE3) using the ModelE subclass object

# %%
model_path = 'allsteps.allmergeSCM_AWARE_788.nc'
my_model = emc2.core.model.ModelE(model_path)

# %% [markdown]
# After that, we load in the HSRL data using the HSRL subclass object.

# %%
HSRL = emc2.core.instruments.HSRL('nsa')
HSRL.read_arm_netcdf_file('awrhsrlM1.20160816.100000.nc')  # raw or processed ARM or ARM-like data file

# %%
HSRL.ds
# Out:
# <xarray.Dataset>
# Dimensions:                                (altitude: 334, mean_time: 120, profile_time: 1, time: 120)
# Coordinates:
#   * time                                   (time) datetime64[ns] 2016-08-16T10:00:00 ... 2016-08-16T10:59:30
#   * mean_time                              (mean_time) object 2016-08-16 10:00:00 ... 2016-08-16 10:59:30
#   * altitude                               (altitude) float32 0.0 ... 9990.0
# Dimensions without coordinates: profile_time
# Data variables:
#     base_time                              object ...
#     first_time                             object ...
#     last_time                              object ...
#     latitude                               (time) float32 dask.array<chunksize=(120,), meta=np.ndarray>
#     longitude                              (time) float32 dask.array<chunksize=(120,), meta=np.ndarray>
#     od                                     (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_od                             (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     od_aerosol                             (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_od_aerosol                     (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     profile_extinction                     (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     extinction                             (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_extinction_aerosol             (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     extinction_aerosol                     (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     beta_a                                 (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     atten_beta_a_backscat                  (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     circular_depol                         (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     linear_depol                           (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_circular_depol                 (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     profile_linear_depol                   (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     beta_a_backscat_parallel               (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_beta_a_backscat_parallel       (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     beta_a_backscat_perpendicular          (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_beta_a_backscat_perpendicular  (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     beta_a_backscat                        (time, altitude) float32 dask.array<chunksize=(120, 334), meta=np.ndarray>
#     profile_beta_a_backscat                (profile_time, altitude) float32 dask.array<chunksize=(1, 334), meta=np.ndarray>
#     qc_mask                                (time, altitude) float64 dask.array<chunksize=(120, 334), meta=np.ndarray>
# Attributes:
#     dpl_py_template:                                                         ...
#     dpl_py_template_version:                                                 ...
#     time_zone:                                                               ...
#     codeversion:                                                             ...
#     codedate:                                                                ...
#     hsrl_instrument:                                                         ...
#     hsrl_altitude_m:                                                         ...
#     hsrl_latitude_degN:                                                      ...
#     hsrl_longitude_degE:                                                     ...
#     hsrl_wavelength_nm:                                                      ...
#     hsrl_processing_parameter__FIR_extinction__enable:                       ...
#     hsrl_processing_parameter__FIR_extinction__range_window:                 ...
#     hsrl_processing_parameter__FIR_extinction__time_constant:                ...
#     hsrl_processing_parameter__FIR_wfov_correction__enable:                  ...
#     hsrl_processing_parameter__FIR_wfov_correction__far_range_average_window:...
#     hsrl_processing_parameter__FIR_wfov_correction__near_far_transistion_rang...
#     hsrl_processing_parameter__FIR_wfov_correction__near_range_average_window...
#     hsrl_processing_parameter__FIR_wfov_correction__time_constant:           ...
#     hsrl_processing_parameter__I2_lock_mask__enable:                         ...
#     hsrl_processing_parameter__I2_lock_mask__lock_lost:                      ...
#     hsrl_processing_parameter__I2_lock_mask__lock_warning:                   ...
#     hsrl_processing_parameter__airborne_extinction_processing__adaptive:     ...
#     hsrl_processing_parameter__airborne_extinction_processing__alt_window_len...
#     hsrl_processing_parameter__airborne_extinction_processing__enable:       ...
#     hsrl_processing_parameter__airborne_extinction_processing__filter_type:  ...
#     hsrl_processing_parameter__airborne_extinction_processing__min_alt:      ...
#     hsrl_processing_parameter__airborne_extinction_processing__od_threshhold:...
#     hsrl_processing_parameter__airborne_extinction_processing__polynomial_ord...
#     hsrl_processing_parameter__airborne_extinction_processing__time_window_le...
#     hsrl_processing_parameter__alternate_cal_dir__full_dir_path:             ...
#     hsrl_processing_parameter__atten_backscat_norm_range__range:             ...
#     hsrl_processing_parameter__averaged_profiles__apply_mask:                ...
#     hsrl_processing_parameter__averaged_profiles__telescope_pointing:        ...
#     hsrl_processing_parameter__cloud_mask__backscat_threshhold:              ...
#     hsrl_processing_parameter__cloud_mask__cloud_buffer_zone:                ...
#     hsrl_processing_parameter__cloud_mask__enable:                           ...
#     hsrl_processing_parameter__cloud_mask__mask_entire_profile:              ...
#     hsrl_processing_parameter__cloud_mask__max_cloud_alt:                    ...
#     hsrl_processing_parameter__color_ratio__angstrom_coef:                   ...
#     hsrl_processing_parameter__compute_stats__enable:                        ...
#     hsrl_processing_parameter__depolarization_is_aerosol_only__enable:       ...
#     hsrl_processing_parameter__extinction_processing__adaptive:              ...
#     hsrl_processing_parameter__extinction_processing__alt_window_length:     ...
#     hsrl_processing_parameter__extinction_processing__enable:                ...
#     hsrl_processing_parameter__extinction_processing__filter_type:           ...
#     hsrl_processing_parameter__extinction_processing__min_alt:               ...
#     hsrl_processing_parameter__extinction_processing__od_threshhold:         ...
#     hsrl_processing_parameter__extinction_processing__polynomial_order:      ...
#     hsrl_processing_parameter__extinction_processing__time_window_length:    ...
#     hsrl_processing_parameter__first_bin_to_process__bin_number:             ...
#     hsrl_processing_parameter__i2a_mol_ratio__enable:                        ...
#     hsrl_processing_parameter__i2a_mol_ratio__filter_window:                 ...
#     hsrl_processing_parameter__i2a_mol_ratio__order:                         ...
#     hsrl_processing_parameter__klett__enable:                                ...
#     hsrl_processing_parameter__klett__lidar_ratio_1064:                      ...
#     hsrl_processing_parameter__klett__lidar_ratio_532:                       ...
#     hsrl_processing_parameter__klett__ref_altitude:                          ...
#     hsrl_processing_parameter__mol_norm_alt__meters:                         ...
#     hsrl_processing_parameter__mol_signal_to_noise_mask__enable:             ...
#     hsrl_processing_parameter__mol_signal_to_noise_mask__threshhold:         ...
#     hsrl_processing_parameter__molecular_smooth__enable:                     ...
#     hsrl_processing_parameter__molecular_smooth__polynomial_order:           ...
#     hsrl_processing_parameter__molecular_smooth__window_length:              ...
#     hsrl_processing_parameter__molecular_spectrum__model:                    ...
#     hsrl_processing_parameter__od_norm_point__meters:                        ...
#     hsrl_processing_parameter__od_norm_point__mode:                          ...
#     hsrl_processing_parameter__od_norm_range__meters:                        ...
#     hsrl_processing_parameter__on_off_zenith_save__enable:                   ...
#     hsrl_processing_parameter__on_off_zenith_save__off_zenith_limit:         ...
#     hsrl_processing_parameter__on_off_zenith_save__zenith_limit:             ...
#     hsrl_processing_parameter__particulate_backscatter_signal_to_noise_mask__...
#     hsrl_processing_parameter__particulate_backscatter_signal_to_noise_mask__...
#     hsrl_processing_parameter__polarization_integration_time__seconds:       ...
#     hsrl_processing_parameter__primary_zaxis_is_range__enable:               ...
#     hsrl_processing_parameter__resampling__range_preaverage:                 ...
#     hsrl_processing_parameter__resampling__time_nan_gaps:                    ...
#     hsrl_processing_parameter__scanning__rti_maximum_off_zenith:             ...
#     hsrl_processing_parameter__scanning__rti_minimum_off_zenith:             ...
#     hsrl_processing_parameter__scanning__rti_skip_scanning:                  ...
#     hsrl_processing_parameter__scanning__rti_skip_scanning_motion:           ...
#     hsrl_processing_parameter__signal_in_dark__enable:                       ...
#     hsrl_processing_parameter__signal_lost_mask__enable:                     ...
#     hsrl_processing_parameter__signal_lost_mask__lost_level:                 ...
#     hsrl_processing_parameter__wfov_corr__correct_below_range:               ...
#     hsrl_processing_parameter__wfov_corr__enable:                            ...
#     hsrl_processing_parameter__wfov_corr__enable_z_fit:                      ...
#     hsrl_processing_parameter__wfov_corr__min_fit_range:                     ...
#     hsrl_processing_parameter__wfov_corr__time_filter_order:                 ...
#     hsrl_processing_parameter__wfov_corr__window_durration:                  ...
#     hsrl_processing_parameter__wfov_corr__z_norm_interval:                   ...
#     _file_dates:                                                             ...
#     _file_times:                                                             ...
#     _datastream:                                                             ...
#     _arm_standards_flag:                                                     ...

# %% [markdown]
# The following command will generate and process 8 subcolumns per time period of simulated HSRL data using the default radiation approach and classify the simulator output.

# %%
my_model = emc2.simulator.main.make_simulated_data(my_model, HSRL, 8, do_classify=True, convert_zeros_to_nan=True)
# Out:
# ## Creating subcolumns...
# Fully overcast cl & ci in 276 voxels
# Fully overcast pl & pi in 385 voxels
# Fully overcast pl & pi in 0 voxels
# Generating lidar moments...
# Generating stratiform lidar variables using radiation logic
# Done! total processing time = 1.27s
# Generating convective lidar variables using radiation logic
# Done! total processing time = 1.49s

# %%
my_model.ds
# Out:
# <xarray.Dataset>
# Dimensions:                     (p: 110, subcolumn: 8, time: 48)
# Coordinates:
#   * p                           (p) float64 979.0 969.0 959.0 ... 0.0075 0.0035
#   * subcolumn                   (subcolumn) int64 0 1 2 3 4 5 6 7
#   * time                        (time) datetime64[ns] 2016-08-16T01:15:00 ... 2016-08-17T00:45:00
#     lon                         float32 166.72
#     lat                         float32 -77.85
# Data variables:
#     axyp                        float32 dask.array<chunksize=(), meta=np.ndarray>
#     prsurf                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     gtempr                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     shflx                       (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lhflx                       (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     ustar                       (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     pblht                       (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     pwv                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     pblht_bp                    (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     u                           (time, p) float32 0.0 ... 0.10967822
#     v                           (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     t                           (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     th                          (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     q                           (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     rhw                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     z                           (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     p_3d                        (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     olr                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     olrcs                       (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lwds                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lwdscs                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lwus                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     swds                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     swus                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     swnscs                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     swdf                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lwdp                        (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     swdp                        (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_sw                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_lw                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_rad                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     lwup                        (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     swup                        (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dq_turb                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_turb                    (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     e_turb                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     km_turb                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     kh_turb                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     ri_turb                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     len_turb                    (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     prec                        (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     mcp                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     ssp                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     cldmc_2d                    (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     cldss_2d                    (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     cldtot_2d                   (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     lwp                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     iwp                         (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     cLWPss                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     pLWPss                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     cIWPss                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     pIWPss                      (time) float32 dask.array<chunksize=(48,), meta=np.ndarray>
#     qcl                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     qci                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     nclic                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     nciic                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldss                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldsscl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldssci                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     qpl                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     qpi                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dtau_ss                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dtau_mc                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dq_mc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_mc                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dq_ss                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_ss                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldssr                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmcr                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     QCLmc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     QCImc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     QPLmc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     QPImc                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_mccl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_mcci                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_mcpl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_mcpi                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     ncl                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     npl                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     nci                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     npi                         (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldsspl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldsspi                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmccl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmcpl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmcci                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     cldmcpi                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_sscl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_ssci                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_sspl                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     re_sspi                     (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dq_ls                       (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_ls                      (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dq_nudge                    (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     dth_nudge                   (time, p) float32 dask.array<chunksize=(48, 110), meta=np.ndarray>
#     conv_frac_subcolumns_cl     (subcolumn, time, p) bool False False ... False
#     conv_frac_subcolumns_ci     (subcolumn, time, p) bool False False ... False
#     conv_frac_subcolumns_pl     (subcolumn, time, p) bool False False ... False
#     conv_frac_subcolumns_pi     (subcolumn, time, p) bool False False ... False
#     strat_frac_subcolumns_cl    (subcolumn, time, p) bool False False ... False
#     strat_frac_subcolumns_ci    (subcolumn, time, p) bool False False ... False
#     strat_frac_subcolumns_pl    (subcolumn, time, p) bool False False ... False
#     strat_frac_subcolumns_pi    (subcolumn, time, p) bool False False ... False
#     strat_q_subcolumns_cl       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_n_subcolumns_cl       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     conv_q_subcolumns_cl        (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_q_subcolumns_ci       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_n_subcolumns_ci       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     conv_q_subcolumns_ci        (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_q_subcolumns_pl       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_n_subcolumns_pl       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     conv_q_subcolumns_pl        (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_q_subcolumns_pi       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_n_subcolumns_pi       (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     conv_q_subcolumns_pi        (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     tau                         (time, p) float32 1.0 0.9977561 ... 0.80303544
#     beta                        (time, p) float32 1.4779139e-05 ... 0.0
#     sigma_180_vol               (time, p) float32 1.7334611e-06 ... 0.0
#     sigma_180                   (time, p) float32 6.133434e-32 ... 0.0
#     sigma                       (time, p) float32 5.229242e-31 ... 0.0
#     kappa                       (time, p) float32 0.10872398 0.108674094 ... 0.0
#     N_s                         (time, p) float32 2.8262487e+25 ... 1.2681895e+20
#     n_s                         (time, p) float32 1.0003088 1.0003045 ... 1.0
#     sub_col_beta_p_tot_strat    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_alpha_p_tot_strat   (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_tot_strat        (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_cl_strat    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_cl_strat     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_cl_strat         (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_ci_strat    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_ci_strat     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_ci_strat         (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_pl_strat    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_pl_strat     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_pl_strat         (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_pi_strat    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_pi_strat     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_pi_strat         (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_beta_att_tot_strat  (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_tot_conv     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_alpha_p_tot_conv    (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_tot_conv         (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_cl_conv     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_cl_conv      (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_cl_conv          (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_ci_conv     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_ci_conv      (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_ci_conv          (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_pl_conv     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_pl_conv      (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_pl_conv          (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_alpha_p_pi_conv     (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_pi_conv      (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_OD_pi_conv          (subcolumn, time, p) float64 0.0 nan ... nan nan
#     sub_col_beta_att_tot_conv   (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_beta_p_tot          (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     sub_col_alpha_p_tot         (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     sub_col_OD_tot              (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     sub_col_beta_att_tot        (subcolumn, time, p) float64 1.733e-06 ... 0.0
#     sub_col_LDR_conv            (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_LDR_strat           (subcolumn, time, p) float64 nan nan ... nan nan
#     sub_col_LDR_tot             (subcolumn, time, p) float64 nan nan ... nan nan
#     ext_mask                    (subcolumn, time, p) float64 0.0 0.0 ... 0.0 0.0
#     strat_phase_mask_HSRL       (subcolumn, time, p) float64 nan nan ... nan nan
#     conv_phase_mask_HSRL        (subcolumn, time, p) float64 nan nan ... nan nan
#     phase_mask_HSRL_all_hyd     (subcolumn, time, p) float64 nan nan ... nan nan
#     conv_COSP_phase_mask        (subcolumn, time, p) float64 nan nan ... nan nan
#     strat_COSP_phase_mask       (subcolumn, time, p) float64 nan nan ... nan nan
#     COSP_phase_mask_all_hyd     (subcolumn, time, p) float64 nan nan ... nan nan
# Attributes:
#     xlabel:               SCM_AWARE_788 SCM_AWARE (AWARE case using the Singl...
#     _file_dates:          ['allsteps']
#     _file_times:          ['allmergeSCM_AWARE_788']
#     _datastream:          act_datastream
#     _arm_standards_flag:  ARMStandardsFlag.OK

# %% [markdown]
# $EMC^2$ can interacts with the [Atmospheric Community Toolkit](https://arm-doe.github.io/ACT) allowing to easily create visualizations. Alternatively, as in the observed and simulated examples below, one can use $EMC^2$'s SubcolumnDisplay subclass object (of ACT's Display class) to generate and save visualizations of both the observation and simulated variables.
# The SubcolumnDisplay plotting routins enable mask arrays to be applied on instrument variables; in this case, observed data is masked where the particulate optical thickness is greater than 4, providing a "cleaner" plots.

# %%
display = emc2.plotting.SubcolumnDisplay(my_model, figsize=(20, 10))
ax, _ = display.plot_instrument_timeseries(HSRL, "beta_a_backscat", log_plot=True, y_range=(0., 2000.),
                                           cmap="viridis", vmin=1e-6, vmax=1e-3,
                                           Mask_array=HSRL.ds["od_aerosol"] > 4.)
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
display.fig.savefig('HSRL_backscatter.png', dpi=200)

# %%
model_display = emc2.plotting.SubcolumnDisplay(my_model, figsize=(20, 10))
ax_mod, _ = model_display.plot_subcolumn_timeseries("sub_col_beta_p_tot", 0, log_plot=True, y_range=(0., 2000.),
                                                 pressure_coords=False, cmap="viridis", vmin=1e-6, vmax=1e-3)
ax_mod.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
display.fig.savefig('HSRL_backscatter_simulated.png', dpi=200)

# %% [markdown]
# We can also use $EMC^2$'s SubcolumnDisplay object to generate profile plots with shaded regions designating variable temporal or spatial (based on all subcolumns) standard deviation.

# %%
model_display_prof = emc2.plotting.SubcolumnDisplay(my_model, figsize=(5,8))
axp = model_display_prof.plot_subcolumn_mean_profile("sub_col_beta_p_tot", "2016-08-16T10:00:00", log_plot=True,
                                                     y_range=(0., 2000.), x_range=(1e-6, 1e-3), color='black',
                                                     pressure_coords=False, alpha=0.2)
axp = model_display_prof.plot_instrument_mean_profile(HSRL, "beta_a_backscat", log_plot=True,
                                                     Mask_array=HSRL.ds["od_aerosol"] > 4.,
                                                     y_range=(0., 2000.), x_range=(1e-6, 1e-3), color="lime",
                                                     pressure_coords=False, alpha=0.2)
display.fig.savefig('HSRL_backscatter_simulated_profile.png', dpi=200)

# %% [markdown]
# Finally, $EMC^2$'s SubcolumnDisplay object also allows easy production of phase classification plots. Here we demonstrate curtain plots of lidar classificaiton for the first subcolumn and frequency phase ratio calculated using all subcolumn data.

# %%
model_display2 = emc2.plotting.SubcolumnDisplay(my_model, figsize=(20,10), subplot_shape=(2, 1))
ax2_1, cb2_1 = model_display2.plot_subcolumn_timeseries("phase_mask_HSRL_all_hyd", 0, y_range=(0., 2000.),
                                                 pressure_coords=False, subplot_index=0)
model_display.change_plot_to_class_mask(cb2_1, variable="phase_mask_HSRL_all_hyd", convert_zeros_to_nan=True)
ax2_1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))

my_model = emc2.simulator.classification.calculate_phase_ratio(my_model, "phase_mask_HSRL_all_hyd", [1])
ax2_2, cb2_2 = model_display2.plot_subcolumn_timeseries("phase_mask_HSRL_all_hyd_fpr", 0, y_range=(0., 2000.),
                                                    pressure_coords=False, cmap="bwr", subplot_index=1,
                                                    cbar_label='Frequency pr (reddish - more liquid)')
ax2_2.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
display.fig.savefig('HSRL_backscatter_simulated_class.png', dpi=200)
